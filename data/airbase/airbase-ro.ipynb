# %%
import pandas as pd

# %%
df = pd.read_csv('AirBase_RO_v6_measurement_configurations.csv', sep="\t")

# %%
df.head()
# Out:
#   station_european_code  component_code component_caption  \
# 0               RO0092A               1               SO2
# 1               RO0092A               5              PM10
# 2               RO0092A               7                O3
# 3               RO0092A               8               NO2
# 4               RO0092A               9               NOX
#
#                          component_name component_FWD  \
# 0                 Sulphur dioxide (air)           yes
# 1  Particulate matter < 10 µm (aerosol)           yes
# 2                           Ozone (air)           yes
# 3                Nitrogen dioxide (air)           yes
# 4                 Nitrogen oxides (air)           yes
#
#    measurement_european_group_code measurement_unit  \
# 0                              100            µg/m3
# 1                              100            µg/m3
# 2                              100            µg/m3
# 3                              100            µg/m3
# ...

# %%
df.tail()
# Out:
#      station_european_code  component_code component_caption  \
# 1409               RO0035A               1               SO2
# 1410               RO0035A               4               SPM
# 1411               RO0035A               8               NO2
# 1412               RO0035A              12                Pb
# 1413               RO0035A              14                Cd
#
#                               component_name component_FWD  \
# 1409                   Sulphur dioxide (air)           yes
# 1410  Total suspended particulates (aerosol)           yes
# 1411                  Nitrogen dioxide (air)           yes
# 1412                          Lead (aerosol)           yes
# 1413                       Cadmium (aerosol)           yes
#
#       measurement_european_group_code measurement_unit  \
# 1409                              100            µg/m3
# 1410                              100            µg/m3
# 1411                              100            µg/m3
# ...
